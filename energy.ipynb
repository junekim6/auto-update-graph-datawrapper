# %%
import pandas as pd

url = "https://en.wikipedia.org/wiki/Rooftop_solar_power#Largest_rooftop_solar_installations"
tables = pd.read_html(url)
len(tables)
# Out:
# 11

# %%
df = tables[4]

# %%
df
# Out:
#                                      PV power station  \
# 0                                        Jining Huaxi
# 1                                        LaiYih Group
# 2               Prologis Redlands Distribution Center
# 3                            Mai Dubai Bottling Plant
# 4                                    AG Heylen Energy
# 5                                          Apple Park
# 6                                      Arvind Limited
# 7                      Warehouse by Permacity / LADWP
# 8                                      General Motors
# 9                        Dera Baba Jaimal Singh, Beas
# 10  Riverside Renewable Energy – Holt Logistics Gl...
# 11  Southern California Edison-Whirlpool Corporati...
# 12                          St. Charles International
# 13          Prologis Rialto I-210 Distribution Center
# 14   NRG Energy-Mandalay Bay Resort Convention Center
# 15              Prologis Perth Amboy Corporation Park
# ...

# %%
df.to_csv("solar.csv", index=False)
